# %%
import pandas as pd
import numpy as np

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pd.set_option("display.max_columns",None)
pd.set_option("display.width",500)
pd.set_option("display.float_format", lambda x: '%.2f' % x)

# %%
df = pd.read_csv("../MTA-metro/dataset/MTA_Subway_Hourly_Ridership__Beginning_February_2022.csv")
# Out:
# /Users/umut/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df.head(20)
# Out:
#          transit_timestamp station_complex_id station_complex borough routes payment_method  ridership  transfers  latitude  longitude                                   Georeference                                   itsuid
# 0   03/27/2022 06:00:00 AM               H007        1 Av (L)       M      L           omny         12          0     40.73     -73.98  POINT (-73.98162841796875 40.730953216552734)    2022-03-27T06:00:00H0071 Av (L)MLomny
# 1   06/05/2022 02:00:00 AM               H007        1 Av (L)       M      L           omny         93          0     40.73     -73.98  POINT (-73.98162841796875 40.730953216552734)    2022-06-05T02:00:00H0071 Av (L)MLomny
# 2   06/13/2023 03:00:00 AM               H007        1 Av (L)       M      L           omny          3          0     40.73     -73.98  POINT (-73.98162841796875 40.730953216552734)    2023-06-13T03:00:00H0071 Av (L)MLomny
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11665628 entries, 0 to 11665627
# Data columns (total 12 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   transit_timestamp   object
#  1   station_complex_id  object
#  2   station_complex     object
#  3   borough             object
#  4   routes              object
#  5   payment_method      object
#  6   ridership           int64
#  7   transfers           int64
#  8   latitude            float64
#  9   longitude           float64
#  10  Georeference        object
#  11  itsuid              object
# dtypes: float64(2), int64(2), object(8)
# memory usage: 1.0+ GB

# %%
df.shape
# Out:
# (11665628, 12)

# %%
df.nunique()
# Out:
# transit_timestamp        14446
# station_complex_id         425
# station_complex            425
# borough                      5
# routes                      96
# payment_method               2
# ridership                 8039
# transfers                 1406
# latitude                   424
# longitude                  424
# Georeference               425
# itsuid                11665628
# dtype: int64

# %%
df.isnull().sum()
# Out:
# transit_timestamp     0
# station_complex_id    0
# station_complex       0
# borough               0
# routes                0
# payment_method        0
# ridership             0
# transfers             0
# latitude              0
# longitude             0
# Georeference          0
# itsuid                0
# dtype: int64

# %%
df.describe([0,0.05,0.50,0.95,0.99,1]).T
# Out:
#                 count   mean    std    min     0%     5%    50%    95%     99%     100%      max
# ridership 11665628.00 153.12 334.67   1.00   1.00   2.00  57.00 583.00 1482.00 14179.00 14179.00
# transfers 11665628.00   6.46  26.67   0.00   0.00   0.00   1.00  26.00   86.00  1560.00  1560.00
# latitude  11665628.00  40.73   0.08  40.58  40.58  40.60  40.72  40.87   40.89    40.90    40.90
# longitude 11665628.00 -73.93   0.06 -74.07 -74.07 -74.01 -73.94 -73.83  -73.78   -73.76   -73.76

# %%
df.describe()
# Out:
#         ridership   transfers    latitude   longitude
# count 11665628.00 11665628.00 11665628.00 11665628.00
# mean       153.12        6.46       40.73      -73.93
# std        334.67       26.67        0.08        0.06
# min          1.00        0.00       40.58      -74.07
# 25%         16.00        0.00       40.68      -73.98
# 50%         57.00        1.00       40.72      -73.94
# 75%        160.00        5.00       40.79      -73.90
# max      14179.00     1560.00       40.90      -73.76

# %%
df.value_counts()
# Out:
# transit_timestamp       station_complex_id  station_complex                     borough  routes        payment_method  ridership  transfers  latitude  longitude  Georeference                                   itsuid
# 01/01/2023 01:00:00 AM  A002                Lexington Av (N,R,W)/59 St (4,5,6)  M        5,N,R,4,,W,6  metrocard       256        18         40.76     -73.97     POINT (-73.96725463867188 40.76266098022461)   2023-01-01T01:00:00A002Lexington Av (N,R,W)/59 St (4,5,6)M5,N,R,4,,W,6metrocard    1
# 08/05/2023 04:00:00 PM  J024                Crescent St (J,Z)                   BK       J,Z           omny            35         0          40.68     -73.87     POINT (-73.87378692626953 40.68319320678711)   2023-08-05T16:00:00J024Crescent St (J,Z)BKJ,Zomny                                  1
# ...

# %%
df["station_complex"].value_counts()
# Out:
# 14 St (A,C,E)/8 Av (L)                                                           28654
# Times Sq-42 St (N,Q,R,W,S,1,2,3,7)/42 St (A,C,E)/Bryant Pk (B,D,F,M)/5 Av (7)    28650
# Grand Central-42 St (S,4,5,6,7)                                                  28649
# 34 St-Herald Sq (B,D,F,M,N,Q,R,W)                                                28648
# 14 St-Union Sq (L,N,Q,R,W,4,5,6)                                                 28648
#                                                                                  ...
# Tompkinsville                                                                    22083
# Bay Pkwy (F)                                                                     21636
# Neptune Av (F)                                                                   21161
# Broad Channel (A,S)                                                              20296
# Beach 105 St (A,S)                                                               19215
# ...

# %% [markdown]
# ### Ridership

# %%
df.groupby("station_complex").describe()
# Out:
#                         ridership                                                transfers                                          latitude                                          longitude
#                             count   mean    std  min   25%    50%    75%     max     count  mean   std  min  25%   50%   75%    max    count  mean  std   min   25%   50%   75%   max     count   mean  std    min    25%    50%    75%    max
# station_complex
# 1 Av (L)                 28295.00 323.90 269.19 1.00 87.00 287.00 477.00 2300.00  28295.00  6.12  6.17 0.00 1.00  4.00 10.00  44.00 28295.00 40.73 0.00 40.73 40.73 40.73 40.73 40.73  28295.00 -73.98 0.00 -73.98 -73.98 -73.98 -73.98 -73.98
# 103 St (1)               28352.00 158.08 134.15 1.00 33.00 142.00 241.00  787.00  28352.00  1.26  1.70 0.00 0.00  1.00  2.00  15.00 28352.00 40.80 0.00 40.80 40.80 40.80 40.80 40.80  28352.00 -73.97 0.00 -73.97 -73.97 -73.97 -73.97 -73.97
# ...

# %%
riderDf = df.groupby("station_complex_id").agg({"ridership": "mean"}).sort_values("ridership",ascending=False)

# %%
riderDf.reset_index(inplace=True)

# %%
riderDf.head(20)
# Out:
#    station_complex_id  ridership
# 0                N060    2809.26
# 1                R238    1527.51
# 2                A022    1273.21
# 3                A034    1122.24
# 4                N095     939.74
# 5                N070     901.48
# 6                N049     843.77
# 7                R135     827.55
# 8                R533     741.58
# 9                R525     740.99
# 10               N094     647.48
# 11               A002     609.62
# 12               N500     600.21
# 13               N305     598.38
# 14               N512     577.97
# 15               N078     575.93
# 16               A043     548.21
# 17               R249     544.22
# 18               R610     526.14
# 19               N080     518.62
